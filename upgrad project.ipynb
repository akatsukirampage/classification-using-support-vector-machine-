# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data=pd.read_csv('/home/ravi/Documents/bank-additional/bank-additional-full.csv',sep=(';'))

# %%
data.rename(columns={'y':'response'}, inplace=True)
data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %%
data['job'].unique()
# Out:
# array(['housemaid', 'services', 'admin.', 'blue-collar', 'technician',
#        'retired', 'management', 'unemployed', 'self-employed', 'unknown',
#        'entrepreneur', 'student'], dtype=object)

# %%
plt.figure(figsize=(15,5))
sns.countplot(data['age'], palette='Set1')
plt.xticks(rotation=90)
plt.title('Distribution of age group', fontsize=20, color='red')
plt.xlabel('Age', fontsize=15)
plt.ylabel('Count', fontsize=15)
plt.show()

# %%
f,(ax1,ax2)=plt.subplots(2,1,figsize=(15,15))
sns.countplot(data[data['response']=='yes']['age'],ax=ax1)
sns.countplot(data[data['response']=='no']['age'],ax=ax2)
plt.xticks(rotation=90)
ax1.set_title('distribution of age group respond positively', fontsize=18,color='green')
ax2.set_title('distribution of age group respond negatively', fontsize=18, color='red')
# Out:
# Text(0.5, 1.0, 'distribution of age group respond negatively')

# %%
f,(ax1,ax2)=plt.subplots(1,2, figsize=(15,7))
sns.countplot(y=data[data['response']=='yes']['job'], ax=ax1)
sns.countplot(y=data[data['response']=='no']['job'], ax=ax2)
plt.tight_layout()
ax1.set_title('repond Positively', fontsize=18,color='green')
ax2.set_title('repond Negatively', fontsize=18, color='red')
# Out:
# Text(0.5, 1.0, 'repond Negatively')

# %%
plt.figure(figsize=(15,5))
with_loan=data[data['loan']=='yes']
sns.countplot(with_loan[with_loan['response']=='yes']['job'],palette='Set1')
plt.xticks(rotation=90)
plt.title('jobs of people reponse positivly even having personal loan', fontsize=15, color='green')
print('number of people having loan repond positivly', len(with_loan[with_loan['response']=='yes']['job']))
# Out:
# number of people having loan repond positivly 683

# %%
with_both_loan=data[data['housing']=='yes'][data[data['housing']=='yes']['loan']=='yes']
plt.figure(figsize=(15,5))
sns.countplot(with_both_loan[with_both_loan['response']=='yes']['job'], palette='Set1')
plt.title('people respond positively even having both home loan and personal loan', fontsize=15, color= 'green')
print('{} of people respond positivly even having both home loan and personal loan '.format(len(with_both_loan[with_both_loan['response']=='yes']['job'])))
# Out:
# 409 of people respond positivly even having both home loan and personal loan

# %%
plt.figure(figsize=(15,5))
sns.countplot(data[data['response']=='yes']['month'])
plt.xticks(rotation=90)
plt.title('which month we get most positive reponse', fontsize=15, color='green')
print(len(data[data['response']=='yes']['month']))
# Out:
# 4640

# %%
plt.figure(figsize=(15,5))
sns.countplot(data[data['response']=='no']['month'])
plt.xticks(rotation=90)
plt.title('which month we get most Negative reponse', fontsize=15, color='green')
print(len(data[data['response']=='no']['month']))
# Out:
# 36548

# %%
plt.figure(figsize=(15,5))
sns.countplot(data[data['response']=='yes']['day_of_week'])
plt.xticks(rotation=90)
plt.title('which week day we get most Positive reponse', fontsize=15, color='green')
print(len(data[data['response']=='yes']['day_of_week']))
# Out:
# 4640

# %%
plt.figure(figsize=(15,5))
sns.countplot(data[data['response']=='no']['day_of_week'])
plt.xticks(rotation=90)
plt.title('which week day we get most Negative reponse', fontsize=15, color='green')
print(len(data[data['response']=='no']['day_of_week']))
# Out:
# 36548

# %%
f, (ax1, ax2)=plt.subplots(1,2,figsize=(15,5))
sns.countplot(data[data['response']=='yes']['marital'], ax=ax1)
sns.countplot(data[data['response']=='no']['marital'],ax=ax2)

ax1.set_title('respond positively', fontsize=15, color='green')
ax2.set_title('respond negatively', fontsize=15, color='red')
plt.tight_layout()

# %%
numeric_data=data._get_numeric_data()
numeric_data.head()
# Out:
#    age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0   56       261         1    999         0           1.1          93.994
# 1   57       149         1    999         0           1.1          93.994
# 2   37       226         1    999         0           1.1          93.994
# 3   40       151         1    999         0           1.1          93.994
# 4   56       307         1    999         0           1.1          93.994
#
#    cons.conf.idx  euribor3m  nr.employed
# 0          -36.4      4.857       5191.0
# 1          -36.4      4.857       5191.0
# 2          -36.4      4.857       5191.0
# 3          -36.4      4.857       5191.0
# 4          -36.4      4.857       5191.0

# %%
plt.figure(figsize=(7,5))
corr=numeric_data.corr()
sns.heatmap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values)

# %%
#from the above heat map we can see the euribor3m,emp.var.rate, cons.price.idx,nr.employed is highly correalted so we can take one of these column and remove the rest for avoiding the multi collinearity

highly_corr=['emp.var.rate', 'cons.price.idx','nr.employed']
data.drop(highly_corr, axis=1, inplace=True)
data.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  duration  campaign  pdays  previous     poutcome  \
# 0   may         mon       261         1    999         0  nonexistent
# 1   may         mon       149         1    999         0  nonexistent
# 2   may         mon       226         1    999         0  nonexistent
# 3   may         mon       151         1    999         0  nonexistent
# 4   may         mon       307         1    999         0  nonexistent
#
#    cons.conf.idx  euribor3m response
# 0          -36.4      4.857       no
# ...

# %%
data.replace('unknown', np.nan, inplace=True)
cols=data.columns
data.isnull().sum()
# Out:
# age                 0
# job               330
# marital            80
# education        1731
# default          8597
# housing           990
# loan              990
# contact             0
# month               0
# day_of_week         0
# duration            0
# campaign            0
# pdays               0
# previous            0
# poutcome            0
# cons.conf.idx       0
# euribor3m           0
# response            0
# dtype: int64

# %%
#here  we can notice all the missing value is present in categorical data 
from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='most_frequent')
data=imp.fit_transform(data)

# %%
data=pd.DataFrame(data, columns=cols)
data.head()
# Out:
#   age        job  marital    education default housing loan    contact month  \
# 0  56  housemaid  married     basic.4y      no      no   no  telephone   may
# 1  57   services  married  high.school      no      no   no  telephone   may
# 2  37   services  married  high.school      no     yes   no  telephone   may
# 3  40     admin.  married     basic.6y      no      no   no  telephone   may
# 4  56   services  married  high.school      no      no  yes  telephone   may
#
#   day_of_week duration campaign pdays previous     poutcome cons.conf.idx  \
# 0         mon      261        1   999        0  nonexistent         -36.4
# 1         mon      149        1   999        0  nonexistent         -36.4
# 2         mon      226        1   999        0  nonexistent         -36.4
# 3         mon      151        1   999        0  nonexistent         -36.4
# 4         mon      307        1   999        0  nonexistent         -36.4
#
#   euribor3m response
# 0     4.857       no
# ...

# %%
data.isnull().sum()
# Out:
# age              0
# job              0
# marital          0
# education        0
# default          0
# housing          0
# loan             0
# contact          0
# month            0
# day_of_week      0
# duration         0
# campaign         0
# pdays            0
# previous         0
# poutcome         0
# cons.conf.idx    0
# euribor3m        0
# response         0
# dtype: int64

# %%
train_x=data.iloc[:,:17]
train_y=data.iloc[:,17]
column_names_for_onehot=set(train_x.columns)-set(numeric_data.columns)
train_x= pd.get_dummies(train_x, columns=column_names_for_onehot, drop_first=True)
train_y=pd.get_dummies(train_y, columns=column_names_for_onehot, drop_first=True)

# %%
x_train=train_x.values
y_train=train_y.values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_train,y_train,test_size=0.25, random_state=0)

# %%
from sklearn.svm import SVC
classifier=SVC(kernel='rbf', random_state=0)
classifier.fit(x_train,y_train)
# Out:
# /home/ravi/.local/lib/python3.6/site-packages/sklearn/utils/validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/ravi/.local/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=0,
#   shrinking=True, tol=0.001, verbose=False)

# %%
y_pred=classifier.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))
# Out:
# 0.8964747013693308
